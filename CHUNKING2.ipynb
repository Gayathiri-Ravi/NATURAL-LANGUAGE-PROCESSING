# %% [markdown]
# # CHUNKING
# Text chunking, also referred to as shallow parsing, is a task that follows Part-Of-Speech Tagging and that adds more structure to the sentence. The result is a grouping of the words in “chunks”. Chunking is a process of extracting phrases from unstructured text, which means analyzing a sentence to identify the constituents(Noun Groups, Verbs, verb groups, etc.) It works on top of POS tagging. It uses POS-tags as input and provides chunks as output.In other words, in a shallow parse tree, there’s one maximum level between the root and the leaves.

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
train_text = state_union.raw("C:/datasets_2119_3569_state_union_1945-Truman.txt")
sample_text = state_union.raw("C:/datasets_2119_3569_state_union_1947-Truman.txt")

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

# %%
tokenized = custom_sent_tokenizer.tokenize(sample_text)

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            result=chunkParser.parse(nltk.pos_tag(train_text))
            print(result)
            chunked.draw()     
    except Exception as e:
        print(str(e))

process_content()
# Out:
# (S
#   (Chunk P/NNP R/NNP E/NNP S/NNP)
#   I/PRP
#   (Chunk
#     D/NNP
#     E/NNP
#     N/NNP
#     T/NNP
#      /NNP
#     H/NNP
#     A/NNP
#     R/NNP
#     R/NNP
#     Y/NNP
#      /NNP
#     S/NNP)
#   ./.
#    /NN
#   (Chunk T/NNP R/NNP U/NNP M/NNP A/NNP N/NNP)
#   '/POS
#   (Chunk S/NNP)
#   (Chunk
#      /VBZ
#     A/NNP
#     D/NNP
#     D/NNP
#     R/NNP
#     E/NNP
#     S/NNP
#     S/NNP
#      /NNP
#     B/NNP
#     E/NNP
#     F/NNP
#     O/NNP
#     R/NNP
#     E/NNP)
#   (Chunk  /VBZ A/NNP  /NNP J/NNP O/NNP)
#   I/PRP
#   (Chunk N/NNP T/NNP  /NNP S/NNP E/NNP S/NNP S/NNP)
#   I/PRP
#   (Chunk
#     O/NNP
#     N/NNP
#      /NNP
#     O/NNP
#     F/NNP
#      /NNP
#     T/NNP
#     H/NNP
#     E/NNP
#      /NNP
#     C/NNP
#     O/NNP
#     N/NNP
#     G/NNP
#     R/NNP
#     E/NNP
#     S/NNP
#     S/NNP
#
# /NNP
#      /NNP)
#   (Chunk
# /VBZ A/NNP p/NN)
#   r/NN
#   i/NN
#   l/VBP
#    /$
#   1/CD
#   6/CD
#   ,/,
#    /VBD
#   1/CD
#   9/CD
#   4/CD
#   5/CD
#
# /NN
#   (Chunk
# /NNP M/NNP r/NN)
#   ./.
#    /CC
#   (Chunk S/NNP)
#   p/VBP
#   e/VBZ
#   a/DT
#   k/NN
#   e/NN
#   r/NN
#   ,/,
#   (Chunk  /NNP M/NNP r/NN)
#   ./.
#    /CC
#   (Chunk P/NNP)
#   r/VBP
#   e/JJ
#   s/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#   (Chunk  /NNP M/NNP e/NN)
#   m/NN
#   b/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/JJ
#   s/NN
#   :/:
#
# /NN
#   I/PRP
#   t/VBP
#    /JJ
#   i/NN
#   s/VBP
#    /IN
#   w/NN
#   i/NN
#   t/VBP
#   h/NN
#    /VBP
#   a/DT
#    /NN
#   h/NN
#   e/VBZ
#   a/DT
#   v/NN
#   y/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   I/PRP
#    /VBP
#   s/JJ
#   t/NN
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   b/NN
#   e/NN
#   f/NN
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP y/NNP)
#   o/MD
#   u/VB
#   ,/,
#   (Chunk  /NNP m/NNP y/NNP  /NNP)
#   f/VBD
#   r/NN
#   i/NN
#   e/VBP
#   n/JJ
#   d/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   l/NN
#   l/NN
#   e/VBZ
#   a/DT
#   g/NN
#   u/JJ
#   e/NN
#   s/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   ./.
#
# /CC
#   (Chunk O/NNP)
#   n/VBP
#   l/NN
#   y/NN
#   (Chunk  /NNP y/NNP e/NN)
#   s/NN
#   t/NN
#   e/NN
#   r/NN
#   d/VBZ
#   a/DT
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   i/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   r/NN
#   t/VBD
#   a/DT
#   l/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   l/NN
#   o/NN
#   v/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP P/NNP r/NN)
#   e/NN
#   s/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#   (Chunk  /NNP F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   k/NN
#   l/NN
#   i/NN
#   (Chunk n/VBP  /NNP D/NNP)
#   e/VBZ
#   l/VBZ
#   a/DT
#   n/JJ
#   o/NN
#   (Chunk  /NNP R/NNP)
#   o/MD
#   o/VB
#   s/JJ
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   t/NN
#   ./.
#    /VB
#   A/DT
#   t/NN
#    /VBZ
#   a/DT
#    /JJ
#   t/NN
#   i/NN
#   m/VBP
#   e/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   k/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/NN
#   s/VBP
#   ,/,
#    /JJ
#   w/NN
#   o/NN
#   r/NN
#   d/NN
#   s/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#   a/DT
#   d/NN
#   e/NN
#   q/NN
#   u/IN
#   a/DT
#   t/NN
#   e/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP e/NN)
#   l/NN
#   o/NN
#   q/NN
#   u/JJ
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   i/NN
#   b/VBP
#   u/JJ
#   t/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   u/JJ
#   l/NN
#   d/NN
#    /NN
#   b/NN
#   e/NN
#    /VBZ
#   a/DT
#    /JJ
#   r/NN
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   l/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   ./.
#
# /CC
#   (Chunk Y/NNP)
#   e/VBP
#   t/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   d/NN
#   e/NN
#   c/NN
#   i/NN
#   s/VBP
#   i/NN
#   v/VBP
#   e/NN
#    /NN
#   h/NN
#   o/NN
#   u/JJ
#   r/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   h/JJ
#   e/NN
#   n/JJ
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP e/NN)
#   v/NN
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   v/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP)
#   r/VBZ
#   a/DT
#   p/NN
#   i/NN
#   d/VBP
#   l/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   o/MD
#   u/VB
#   r/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   l/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   s/VBP
#   u/JJ
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   t/NN
#   o/NN
#   o/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP g/NN)
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NN
#   f/NN
#   o/NN
#   r/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   e/JJ
#   m/NN
#   i/NN
#   e/VBP
#   s/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   (Chunk H/NNP i/NN)
#   s/VBP
#    /NN
#   i/NN
#   n/VBP
#   f/NN
#   i/NN
#   n/VBP
#   i/NN
#   t/VBP
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   s/VBP
#   d/NN
#   o/NN
#   m/NN
#   ,/,
#   (Chunk  /VB A/NNP l/NN)
#   m/NN
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   y/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   (Chunk d/VB  /NNP)
#   h/VB
#   a/DT
#   s/JJ
#    /NN
#   s/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP f/NN)
#   i/NN
#   t/VBP
#    /JJ
#   t/NN
#   o/NN
#   (Chunk  /NNP)
#   t/VBZ
#   a/DT
#   k/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#    /VBD
#   a/DT
#    /NN
#   g/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   n/JJ
#    /NN
#   w/NN
#   h/NN
#   o/JJ
#   (Chunk  /NNP l/NN)
#   o/NN
#   v/NN
#   e/NN
#   d/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   l/NN
#   o/NN
#   v/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   ,/,
#    /VB
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/VBZ
#   a/DT
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   ./.
#
# /CC
#   (Chunk N/NNP)
#   (Chunk o/VBP  /NNP)
#   m/FW
#   a/DT
#   n/JJ
#   (Chunk  /NNP c/NN)
#   o/NN
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   s/NN
#   s/NN
#   i/NN
#   b/VBP
#   l/NN
#   y/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   d/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP v/NN)
#   o/NN
#   i/NN
#   d/VBP
#    /JJ
#   l/NN
#   e/NN
#   f/NN
#   t/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP n/NN)
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   u/JJ
#   l/NN
#   ./.
#    /CC
#   (Chunk N/NNP)
#   (Chunk o/VBP  /NNP w/NN)
#   o/NN
#   r/NN
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   e/VBZ
#   a/DT
#   s/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   c/JJ
#   h/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   h/NN
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP u/NN)
#   n/NN
#   t/NN
#   o/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   l/VBP
#   l/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP e/NN)
#   v/NN
#   e/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   r/VBZ
#   a/DT
#   c/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   c/VBZ
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   l/NN
#   o/NN
#   r/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP k/NN)
#   (Chunk n/NNP)
#   o/VBZ
#   w/JJ
#   s/JJ
#    /NN
#   i/NN
#   t/VBP
#    /NN
#   h/NN
#   a/DT
#   s/JJ
#    /NN
#   l/NN
#   o/NN
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#    /JJ
#   h/NN
#   e/NN
#   r/NN
#   o/NN
#   i/NN
#   (Chunk c/VBP  /NNP)
#   c/VBP
#   h/VBZ
#   a/DT
#   m/NN
#   p/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#   i/NN
#   c/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/JJ
#   m/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   r/VBP
#   a/DT
#   g/NN
#   i/NN
#   (Chunk c/VBP  /NNP)
#   f/VBP
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/JJ
#    /NN
#   t/NN
#   h/NN
#   r/NN
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP u/NN)
#   s/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   o/NN
#   n/IN
#   s/NN
#   i/NN
#   b/VBP
#   i/NN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   e/VBP
#   s/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   r/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP o/NN)
#   n/NN
#   ./.
#   (Chunk O/NNP)
#   u/JJ
#   r/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   d/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   v/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP l/NN)
#   o/NN
#   o/NN
#   k/NN
#   e/FW
#   d/NN
#    /NN
#   b/VBD
#   a/DT
#   c/NN
#   k/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk H/NNP e/NN)
#   (Chunk  /NNP l/NN)
#   o/NN
#   o/NN
#   k/NN
#   e/FW
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   v/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk T/NNP h/NN)
#   a/DT
#   t/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   w/NN
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   o/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   a/DT
#   t/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   w/NN
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP d/NN)
#   o/NN
#   ./.
#
# /CC
#   (Chunk S/NNP)
#   (Chunk o/VBP  /NNP m/NN)
#   u/JJ
#   c/NN
#   h/NN
#   (Chunk  /NNP b/NN)
#   l/NN
#   o/NN
#   o/NN
#   d/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/JJ
#    /NN
#   a/DT
#   l/NN
#   r/NN
#   e/VBZ
#   a/DT
#   d/NN
#   y/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP s/NN)
#   h/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   d/VBP
#   e/VBZ
#   a/DT
#   l/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP c/NN)
#   h/NN
#   e/IN
#   r/NN
#   i/NN
#   s/VBP
#   h/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   k/NN
#   l/NN
#   i/NN
#   (Chunk n/VBP  /NNP D/NNP)
#   e/VBZ
#   l/VBZ
#   a/DT
#   n/JJ
#   o/NN
#   (Chunk  /NNP R/NNP)
#   o/MD
#   o/VB
#   s/JJ
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   t/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   v/VBP
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   e/VBP
#   d/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   h/VB
#   a/DT
#   t/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   t/VBP
#    /JJ
#   e/NN
#   v/NN
#   e/NN
#   n/JJ
#    /VBZ
#   a/DT
#    /JJ
#   m/NN
#   o/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   u/JJ
#   s/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   c/VBP
#   t/NN
#   o/NN
#   r/NN
#   y/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   o/VBP
#   d/VBZ
#   a/DT
#   y/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   n/IN
#   t/NN
#   i/NN
#   r/VBP
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   l/NN
#   o/NN
#   o/IN
#   k/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   f/NN
#   o/NN
#   r/NN
#   (Chunk  /NNP e/NN)
#   n/IN
#   l/NN
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   e/NN
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   h/NN
#   i/JJ
#   p/VBP
#    /JJ
#   t/NN
#   o/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   ./.
#    /CC
#   (Chunk S/NNP)
#   u/JJ
#   c/NN
#   h/NN
#    /VBZ
#   a/DT
#    /JJ
#   l/NN
#   e/VBZ
#   a/DT
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   h/NN
#   i/JJ
#   p/VBP
#    /JJ
#   r/NN
#   e/NN
#   q/IN
#   u/JJ
#   i/NN
#   r/VBP
#   e/NN
#   s/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   s/VBP
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   r/NN
#   a/DT
#   g/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   l/NN
#   e/NN
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   ./.
#    /NN
#   I/PRP
#   t/VBP
#    /JJ
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   v/NN
#   i/NN
#   d/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#    /NN
#   b/NN
#   y/NN
#    /VBZ
#   a/DT
#    /JJ
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   e/NN
#   p/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   o/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   g/VBP
#   h/NN
#   e/NN
#   s/NN
#   t/IN
#    /NN
#   i/NN
#   d/VBP
#   e/VBZ
#   a/DT
#   l/NN
#   s/NN
#   ./.
#
# /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#    /NN
#   g/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#    /NN
#   h/NN
#   u/JJ
#   m/NN
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   y/NN
#    /NN
#   I/PRP
#    /VBP
#   c/VBG
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP h/NN)
#   e/NN
#   l/NN
#   p/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   (Chunk  /NNP k/NN)
#   e/NN
#   e/NN
#   p/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP u/NN)
#   n/NN
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP d/NN)
#   e/NN
#   f/JJ
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#    /NN
#   i/NN
#   d/VBP
#   e/VBZ
#   a/DT
#   l/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP h/NN)
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   l/NN
#   o/NN
#   q/NN
#   u/JJ
#   e/NN
#   n/JJ
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   c/JJ
#   l/NN
#   a/DT
#   i/JJ
#   m/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   k/NN
#   l/NN
#   i/NN
#   n/VBP
#    /JJ
#   (Chunk R/NNP o/NN)
#   o/NN
#   s/NN
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   t/NN
#   ./.
#
# /NN
#   I/PRP
#    /VBP
#   w/WRB
#   a/DT
#   n/JJ
#   t/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   u/JJ
#   r/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP f/NN)
#   e/NN
#   l/NN
#   l/NN
#   o/NN
#   w/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#   s/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   o/JJ
#   (Chunk  /NNP l/NN)
#   o/NN
#   v/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   b/VBP
#   e/NN
#   r/NN
#   t/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   o/NN
#   u/JJ
#   g/NN
#   h/NN
#   o/JJ
#   u/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   I/PRP
#    /VBP
#   w/JJ
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   p/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   f/JJ
#   e/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#    /NN
#   i/NN
#   d/VBP
#   e/VBZ
#   a/DT
#   l/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#    /VBP
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   a/DT
#   t/NN
#    /NN
#   i/NN
#   (Chunk s/VBP  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   I/PRP
#    /VBP
#   s/JJ
#   h/NN
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   i/NN
#   r/VBP
#   k/NN
#   (Chunk  /NNP i/NN)
#   t/NN
#   ./.
#
# /CC
#   (Chunk S/NNP)
#   (Chunk o/VBP  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP p/NN)
#   o/NN
#   s/NN
#   s/NN
#   i/NN
#   b/VBP
#   l/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   s/VBP
#   u/JJ
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   t/VBD
#   a/DT
#   n/JJ
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   o/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP G/NNP e/NN)
#   r/NN
#   m/VBD
#   a/DT
#   n/JJ
#   y/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP J/NNP)
#   a/DT
#   p/NN
#   a/DT
#   n/JJ
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP c/NN)
#   e/NN
#   r/NN
#   t/IN
#   a/DT
#   i/NN
#   n/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   e/NN
#   y/NN
#   o/NN
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP s/NN)
#   h/VBD
#   a/DT
#   d/NN
#   o/NN
#   w/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   (Chunk  /NNP d/NN)
#   o/NN
#   u/JJ
#   b/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   h/VB
#   a/DT
#   t/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP u/NN)
#   n/NN
#   t/NN
#   i/NN
#   l/VBP
#    /JJ
#   n/JJ
#   o/NN
#   (Chunk  /NNP v/NN)
#   e/NN
#   s/VBD
#   t/NN
#   i/NN
#   g/VBP
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/VBD
#   a/DT
#   i/JJ
#   n/JJ
#   s/NN
#   !/.
#
# /JJ
#   (Chunk W/NNP e/NN)
#    /VBD
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   e/NN
#   p/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   s/NN
#   c/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   c/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP m/NN)
#   u/JJ
#   c/NN
#   h/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   t/NN
#   i/NN
#   l/VBP
#   l/NN
#    /VBP
#   a/DT
#   h/NN
#   e/VBZ
#   a/DT
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP u/NN)
#   s/NN
#   ./.
#   (Chunk
# /VB H/NNP)
#   a/DT
#   v/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   c/NN
#   h/NN
#    /VBZ
#   a/DT
#    /JJ
#   h/NN
#   e/VBZ
#   a/DT
#   v/NN
#   y/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   k/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NN
#   p/NN
#   l/NN
#   e/NN
#   t/NN
#   e/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   c/VBP
#   t/NN
#   o/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP c/NN)
#   e/NN
#   r/NN
#   t/IN
#   a/DT
#   i/NN
#   n/NN
#   ,/,
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   v/NN
#   e/NN
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   c/NN
#   o/IN
#   m/JJ
#   e/NN
#    /VBD
#   a/DT
#    /JJ
#   p/NN
#   a/DT
#   r/NN
#   t/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP p/NN)
#   l/NN
#   a/DT
#   n/JJ
#    /NN
#   f/NN
#   o/NN
#   r/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   i/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   c/VBP
#   t/NN
#   o/NN
#   r/NN
#   y/NN
#   !/.
#
# /JJ
#   (Chunk T/NNP o/NN)
#   (Chunk  /NNP s/NN)
#   e/NN
#   t/NN
#   t/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   r/NN
#   e/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   o/NN
#   t/NN
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   e/NN
#   m/NN
#   p/NN
#   o/NN
#   r/NN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/VBD
#   p/NN
#   i/NN
#   t/VBP
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   r/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP j/NN)
#   e/NN
#   o/VBP
#   p/NN
#   a/DT
#   r/NN
#   d/NN
#   i/NN
#   z/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   t/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ./.
#
# /JJ
#   (Chunk O/NNP u/NN)
#   r/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   m/VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   t/VBP
#    /JJ
#   r/NN
#   e/NN
#   m/VBD
#   a/DT
#   i/JJ
#   n/NN
#   s/SYM
#   -/:
#   (Chunk U/NNP)
#   n/MD
#   c/VB
#   o/JJ
#   n/JJ
#   d/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP S/NNP)
#   u/JJ
#   r/NN
#   r/NN
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   !/.
#    /JJ
#   (Chunk W/NNP e/NN)
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   a/DT
#   f/JJ
#   f/NN
#   i/NN
#   c/VBP
#    /IN
#   w/NN
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   k/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   e/NN
#   r/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   o/NN
#   n/IN
#   s/NN
#   i/NN
#   b/VBP
#   i/NN
#   l/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   k/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/NN
#   e/SYM
#   -/:
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   t/VBP
#    /NN
#   i/NN
#   s/VBP
#    /PDT
#   a/DT
#    /JJ
#   v/NN
#   e/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   o/NN
#   n/IN
#   s/NN
#   i/NN
#   b/VBP
#   i/NN
#   l/NN
#   i/NN
#   t/VBP
#   y/SYM
#   -/:
#   m/NN
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   f/JJ
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   e/VBP
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   c/VBP
#   o/JJ
#   n/JJ
#   s/NN
#   c/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   c/VBP
#   t/IN
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/VBZ
#   a/DT
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP d/NN)
#   o/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   s/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   n/JJ
#   e/NN
#   c/NNS
#   e/VBP
#   s/JJ
#   s/NN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   r/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   j/NN
#   u/JJ
#   s/NN
#   t/NN
#   i/NN
#   f/VBP
#   i/NN
#   e/VBP
#   d/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   f/NN
#   f/NN
#   e/NN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   ./.
#    /NN
#   (Chunk B/NNP u/NN)
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   w/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP G/NNP)
#   o/MD
#    /VB
#   d/NN
#    /IN
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP m/NN)
#   a/DT
#   n/JJ
#    /NN
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP v/NN)
#   i/NN
#   o/VBP
#   l/NN
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   u/NN
#   i/NN
#   l/VBP
#   t/NN
#   y/NN
#   (Chunk  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   p/JJ
#   u/JJ
#   n/NN
#   i/NN
#   s/VBP
#   h/NN
#   e/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk N/NNP o/NN)
#   t/NN
#   h/NN
#   i/JJ
#   n/VBP
#   g/JJ
#   (Chunk  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   a/DT
#   k/NN
#   e/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   t/NN
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   n/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   u/JJ
#   n/NN
#   i/NN
#   s/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   r/NN
#   i/JJ
#   m/NN
#   i/NN
#   n/VBP
#   a/DT
#   l/NN
#   s/NN
#   (Chunk  /NNP e/NN)
#   v/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   u/JJ
#   g/NN
#   h/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP p/NN)
#   u/JJ
#   r/NN
#   s/NN
#   u/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   m/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   d/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   h/NN
#   ./.
#   (Chunk
# /VB L/NNP)
#   a/DT
#   s/JJ
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   n/JJ
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   e/NN
#   d/NN
#    /NN
#   i/NN
#   f/VBP
#    /JJ
#   w/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   t/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   p/JJ
#   p/NN
#   o/NN
#   n/JJ
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   l/NN
#   o/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   t/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   r/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#    /VBP
#   a/DT
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   u/JJ
#   n/JJ
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   t/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#    /SYM
#   -/:
#    /NN
#   h/NN
#   o/JJ
#   w/NN
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   t/IN
#   a/DT
#   n/JJ
#   t/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   s/NN
#   h/NN
#   r/NN
#   i/NN
#   n/VBP
#   k/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ,/,
#    /VBP
#   i/JJ
#   t/VBP
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   f/NN
#   u/JJ
#   t/NN
#   i/NN
#   l/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   e/NN
#   k/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   f/JJ
#   e/NN
#   t/NN
#   y/NN
#    /NN
#   b/NN
#   e/NN
#   h/NN
#   i/JJ
#   n/VBP
#   d/JJ
#   (Chunk  /NNP g/NN)
#   e/NN
#   o/NN
#   g/NN
#   r/VBZ
#   a/DT
#   p/NN
#   h/NN
#   i/JJ
#   c/VBP
#   a/DT
#   l/NN
#    /NN
#   b/VBD
#   a/DT
#   r/NN
#   r/NN
#   i/NN
#   e/VBP
#   r/NN
#   s/NN
#   ./.
#    /CC
#   (Chunk R/NNP)
#   e/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP l/NN)
#   a/DT
#   w/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#   i/NN
#   c/VBP
#   e/NN
#   ./.
#
# /CC
#   (Chunk H/NNP)
#   e/VBP
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /PDT
#   (Chunk A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ,/,
#    /JJ
#   w/NN
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   b/NN
#   o/NN
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP l/NN)
#   o/NN
#   n/JJ
#   g/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   c/JJ
#   h/NN
#   i/NN
#   e/VBP
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#    /JJ
#   s/NN
#   o/IN
#   c/NN
#   i/VBP
#   a/DT
#   l/NN
#    /NN
#   o/NN
#   r/NN
#   d/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   t/NN
#   h/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#    /NN
#   h/NN
#   e/NN
#   r/NN
#   i/NN
#   t/VBP
#   a/DT
#   g/NN
#   e/NN
#   ./.
#    /NN
#   I/PRP
#   n/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP t/NN)
#   i/NN
#   m/VBP
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   r/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   d/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP m/NN)
#   a/DT
#   d/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/NN
#    /VBZ
#   a/DT
#    /JJ
#   r/NN
#   e/VBZ
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   m/NN
#   o/NN
#   c/VBP
#   r/VB
#   a/DT
#   t/NN
#   i/NN
#   (Chunk c/VBP  /NNP)
#   w/VBP
#   a/DT
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP l/NN)
#   i/NN
#   f/VBP
#   e/NN
#   ./.
#    /CC
#   (Chunk L/NNP)
#   e/VBP
#   t/JJ
#   (Chunk  /NNP m/NN)
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   w/VBD
#   a/DT
#   r/NN
#   d/SYM
#   -/:
#   l/NN
#   o/NN
#   o/IN
#   k/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   (Chunk A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   t/NN
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#    /NN
#   i/NN
#   l/VBP
#   l/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/VBZ
#   a/DT
#   x/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP e/NN)
#   f/NN
#   f/NN
#   o/NN
#   r/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   r/NN
#   o/NN
#   v/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   o/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NNS
#   m/VBP
#   o/JJ
#   n/JJ
#    /NN
#   p/NN
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   f/VBP
#   f/NN
#   i/NN
#   c/VBP
#   u/JJ
#   l/NN
#   t/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   y/NN
#   s/NN
#    /VBZ
#   a/DT
#   h/NN
#   e/VBZ
#   a/DT
#   d/NN
#   ,/,
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   q/JJ
#   u/JJ
#   e/NN
#   s/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   b/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP s/NN)
#   t/VBD
#   a/DT
#   g/NN
#   g/NN
#   e/NN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   ./.
#    /CC
#   (Chunk H/NNP)
#   o/VBP
#   w/JJ
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#   ,/,
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   i/JJ
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   t/NN
#   h/NN
#   e/NN
#   r/NN
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP d/NN)
#   o/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP)
#   f/VBZ
#   e/VB
#   a/DT
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   t/NN
#   u/JJ
#   r/NN
#   e/NN
#   ./.
#
# /CC
#   (Chunk O/NNP)
#   (Chunk n/VBP  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   b/VBZ
#   a/DT
#   t/NN
#   t/NN
#   l/NN
#   e/NN
#   f/NN
#   i/NN
#   e/VBP
#   l/NN
#   d/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP)
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   q/NN
#   u/JJ
#   e/NN
#   n/JJ
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   v/FW
#   e/FW
#   r/NN
#   w/NN
#   h/NN
#   e/NN
#   l/NN
#   m/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   d/JJ
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   -/:
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   n/NN
#   !/.
#    /VB
#   A/DT
#   t/NN
#    /NN
#   h/NN
#   o/JJ
#   m/NN
#   e/NN
#   ,/,
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   o/NN
#   l/NN
#   u/JJ
#   t/NN
#   e/NN
#   !/.
#    /JJ
#   (Chunk W/NNP e/NN)
#   (Chunk  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   v/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   e/VB
#   a/DT
#   s/JJ
#   e/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   u/JJ
#   g/NN
#   g/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   r/NN
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   i/JJ
#   n/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /VBD A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   w/VBD
#   a/DT
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP l/NN)
#   i/NN
#   f/VBP
#   e/NN
#   ./.
#
# /VB
#   A/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   m/NN
#   o/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ,/,
#    /VBZ
#   a/DT
#   l/NN
#   o/NN
#   n/JJ
#   g/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#    /NN
#   h/NN
#   e/NN
#   r/NN
#    /NN
#   b/NN
#   r/NN
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   A/DT
#   l/NN
#   l/NN
#   i/NN
#   e/VBP
#   s/NN
#   ,/,
#    /VBP
#   i/JJ
#   s/VBP
#    /JJ
#   p/NN
#   a/DT
#   y/NN
#   i/NN
#   n/VBP
#   g/NN
#    /VBP
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#    /VB
#   a/DT
#    /NN
#   h/NN
#   e/VBZ
#   a/DT
#   v/NN
#   y/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   f/JJ
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/JJ
#   m/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   (Chunk  /NNP)
#   c/VBZ
#   h/VB
#   a/DT
#   r/NN
#   a/DT
#   c/NN
#   t/NN
#   e/IN
#   r/NN
#   i/NN
#   s/VBP
#   t/NN
#   i/NN
#   c/VBP
#    /JJ
#   e/NN
#   n/NN
#   e/NN
#   r/NN
#   g/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#    /FW
#   a/DT
#   r/NN
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   s/VBP
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   b/VBP
#   e/NN
#   r/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP e/NN)
#   n/IN
#   t/NN
#   i/NN
#   r/VBP
#   e/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   ./.
#    /CC
#   (Chunk G/NNP)
#   r/VBP
#   a/DT
#   d/NN
#   u/IN
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   h/VBD
#   a/DT
#   c/JJ
#   k/NN
#   l/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP s/NN)
#   l/NN
#   a/DT
#   v/NN
#   e/NN
#   r/NN
#   y/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   b/NN
#   r/NN
#   o/NN
#   k/NN
#   e/FW
#   n/JJ
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   (Chunk  /NNP h/NN)
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/JJ
#   m/NN
#   ./.
#
# /VB
#   A/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP u/NN)
#   s/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   a/DT
#   y/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#    /VBZ
#   a/DT
#    /JJ
#   s/NN
#   p/NN
#   e/NN
#   e/NN
#   d/NN
#   y/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   c/VBP
#   t/NN
#   o/NN
#   r/NN
#   y/NN
#   ./.
#    /CC
#   (Chunk E/NNP)
#   v/VBP
#   e/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /NN
#   i/NN
#   (Chunk s/VBP  /NNP d/NN)
#   e/NN
#   l/VBZ
#   a/DT
#   y/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   s/JJ
#   t/NN
#   s/NN
#    /VBZ
#   a/DT
#    /JJ
#   t/NN
#   e/NN
#   r/NN
#   r/NN
#   i/NN
#   b/VBP
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   l/NN
#   l/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#    /FW
#   a/DT
#   r/NN
#   m/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   b/VBP
#   e/NN
#   r/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   d/VBZ
#   a/DT
#   y/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#    /NN
#   b/IN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   n/JJ
#    /NN
#   e/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP H/NNP i/NN)
#   t/VBP
#   l/NN
#   e/NN
#   r/NN
#   '/''
#   s/JJ
#   (Chunk  /NNP g/NN)
#   h/VBD
#   a/DT
#   s/JJ
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   o/IN
#   m/NN
#   i/NN
#   n/VBP
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk T/NNP o/NN)
#   k/NN
#   (Chunk y/NNP o/NN)
#   (Chunk  /NNP r/NN)
#   o/NN
#   c/NN
#   k/NN
#   s/JJ
#   (Chunk  /NNP u/NN)
#   n/NN
#   d/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#    /NN
#   b/NN
#   o/NN
#   m/NN
#   b/NN
#   s/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP g/NN)
#   r/NN
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/VBZ
#   a/DT
#   t/NN
#   e/NN
#   g/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP N/NNP)
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#   s/JJ
#   '/''
#    /JJ
#   w/IN
#   a/DT
#   r/NN
#    /NN
#   h/VBD
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   t/NN
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   n/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   -/:
#    /NN
#   d/NN
#   u/JJ
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   n/JJ
#   o/NN
#   (Chunk  /NNP)
#   s/VBZ
#   m/VB
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP m/NN)
#   e/VBZ
#   a/DT
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   s/VBP
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   m/VB
#   m/VB
#   a/DT
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP C/NNP h/NN)
#   i/NN
#   e/VBP
#   f/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   e/VBP
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   w/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   r/NN
#   r/NN
#   y/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   u/JJ
#   t/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/VBZ
#   a/DT
#   t/NN
#   e/NN
#   g/NN
#   y/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/VBP
#   e/JJ
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   r/VBP
#   e/NN
#   c/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /VBZ A/NNP d/NN)
#   m/NN
#   i/NN
#   r/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP L/NNP)
#   e/VBZ
#   a/DT
#   h/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP G/NNP e/NN)
#   n/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP M/NNP)
#   a/DT
#   r/NN
#   s/NN
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   ,/,
#   (Chunk  /VB A/NNP  /NNP d/NN)
#   m/NN
#   i/NN
#   r/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP K/NNP i/NNP)
#   n/MD
#   g/VB
#   ,/,
#   (Chunk  /NNP G/NNP e/NN)
#   n/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#    /VBZ
#   A/DT
#   r/NN
#   n/JJ
#   o/NN
#   l/NN
#   d/NN
#   ,/,
#   (Chunk  /NNP G/NNP e/NN)
#   n/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP E/NNP i/NN)
#   s/VBP
#   e/NN
#   n/JJ
#   h/NN
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   ,/,
#   (Chunk  /VB A/NNP)
#   d/JJ
#   m/NN
#   i/NN
#   r/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP N/NNP)
#   i/VBP
#   m/VBP
#   i/JJ
#   t/VBP
#   z/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP G/NNP e/NN)
#   n/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP M/NNP)
#   a/DT
#   c/NN
#   (Chunk A/NNP r/NN)
#   t/NN
#   h/NN
#   u/JJ
#   r/NN
#   ./.
#
# /NN
#   I/PRP
#    /VBP
#   w/WRB
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   n/IN
#   t/NN
#   i/NN
#   r/VBP
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP k/NN)
#   (Chunk n/NNP)
#   o/VBZ
#   w/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   d/NN
#   i/NN
#   r/VBP
#   e/NN
#   c/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/VBD
#   a/DT
#   i/NN
#   n/SYM
#   -/:
#   u/JJ
#   n/JJ
#   c/NN
#   h/VBD
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   h/VBP
#   a/DT
#   m/NN
#   p/NN
#   e/NN
#   r/NN
#   e/NN
#   d/NN
#   !/.
#
# /JJ
#   (Chunk O/NNP u/NN)
#   r/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   b/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   e/NN
#   r/NN
#   o/NN
#   i/NN
#   (Chunk c/VBP  /NNP m/NN)
#   e/NN
#   n/JJ
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   v/VBZ
#   a/DT
#   l/NN
#   i/NN
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   m/NN
#   e/NN
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   r/NN
#   v/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   n/JJ
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   p/IN
#   a/DT
#   i/JJ
#   d/NN
#   ./.
#    /JJ
#   (Chunk T/NNP h/NN)
#   e/NN
#   y/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/JJ
#   y/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   g/NN
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   t/VBP
#   u/JJ
#   d/NN
#   e/NN
#   ./.
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   v/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   g/NN
#   e/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   (Chunk r/VBP  /NNP)
#   s/VBD
#   a/DT
#   c/JJ
#   r/NN
#   i/NN
#   f/VBP
#   i/JJ
#   c/VBP
#   e/JJ
#   s/NN
#   ./.
#    /NN
#   (Chunk B/NNP e/NN)
#   c/VBZ
#   a/DT
#   u/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   c/JJ
#   r/NN
#   i/NN
#   f/VBP
#   i/JJ
#   c/VBP
#   e/JJ
#   s/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   w/JJ
#   n/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#   i/NN
#   c/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   o/NN
#   u/JJ
#   g/NN
#   h/NN
#   o/JJ
#   u/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   (Chunk  /NNP e/NN)
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP s/NN)
#   l/NN
#   o/NN
#   w/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   s/NN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP g/NN)
#   l/NN
#   e/VBZ
#   a/DT
#   m/NN
#    /VBZ
#   a/DT
#   c/JJ
#   r/NN
#   o/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   r/NN
#   i/NN
#   z/VBP
#   o/JJ
#   n/NN
#   ./.
#
# /CC
#   (Chunk O/NNP)
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   e/NN
#   f/VBD
#   a/DT
#   t/NN
#   h/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   m/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP r/NN)
#   u/JJ
#   g/NN
#   g/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   o/JJ
#   r/NN
#   e/NN
#   (Chunk s/VBD  /NNP i/NN)
#   n/VBP
#    /JJ
#   s/NN
#   e/VBZ
#   a/DT
#   r/NN
#   c/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/NN
#   i/NN
#   g/VBP
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   l/NN
#   e/NN
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   p/VBZ
#   o/IN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#    /NN
#   f/NN
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/IN
#   m/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   e/VBZ
#   c/JJ
#   o/JJ
#   n/JJ
#   o/IN
#   m/NN
#   i/NN
#   c/VBP
#    /JJ
#   o/JJ
#   p/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   ./.
#    /CC
#   (Chunk F/NNP)
#   o/VBP
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   n/JJ
#   d/NN
#   a/DT
#   m/NN
#   e/NN
#   n/JJ
#   t/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP r/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#   (Chunk  /NNP r/NN)
#   i/NN
#   s/VBP
#   k/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   r/VBP
#    /IN
#   l/NN
#   i/NN
#   v/VBP
#   e/NN
#   s/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP w/NN)
#   e/NN
#   l/NN
#   l/NN
#   (Chunk  /NNP k/NN)
#   (Chunk n/NNP)
#   o/VBZ
#   w/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   d/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   c/NN
#   h/NN
#   (Chunk  /NNP r/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   r/NN
#   v/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   s/NN
#   t/VBD
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   g/VBP
#   i/NN
#   l/VBP
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   t/NN
#   e/NN
#   r/NN
#   n/IN
#   a/DT
#   l/NN
#    /NN
#   p/NN
#   r/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP l/NN)
#   i/NN
#   b/VBP
#   e/NN
#   r/NN
#   t/NN
#   y/NN
#   !/.
#
# /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   i/NN
#   n/VBP
#    /PDT
#   a/DT
#   n/JJ
#    /NN
#   h/NN
#   o/NN
#   u/JJ
#   r/NN
#    /VBD
#   a/DT
#   f/JJ
#   t/NN
#   e/NN
#   r/NN
#    /NN
#   I/PRP
#    /VBP
#   t/JJ
#   o/NN
#   o/NN
#   k/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   a/DT
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   f/NN
#   i/NN
#   c/VBP
#   e/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   a/DT
#   n/JJ
#   n/NN
#   o/NN
#   u/JJ
#   n/JJ
#   c/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP S/NNP)
#   a/DT
#   n/JJ
#    /NN
#   (Chunk F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   i/NN
#   s/VBP
#   c/NN
#   o/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   f/JJ
#   e/NN
#   r/NN
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   c/JJ
#   e/NN
#   e/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk W/NNP e/NN)
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   m/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   r/NN
#   a/DT
#   g/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   b/NN
#   l/NN
#   e/NN
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP w/NN)
#   a/DT
#   r/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   m/NN
#   o/NN
#   r/NN
#   y/NN
# ...
#   (Chunk r/VB  /NNP)
#   c/VB
#   o/JJ
#   l/NN
#   o/NN
#   r/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP s/NN)
#   u/JJ
#   p/NN
#   p/NN
#   o/NN
#   r/NN
#   t/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP e/NN)
#   f/NN
#   f/NN
#   o/NN
#   r/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   b/IN
#   u/JJ
#   i/NN
#   l/VBP
#   d/NN
#    /VBP
#   a/DT
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   o/NN
#   n/JJ
#   g/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP N/NNP)
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP O/NNP r/NN)
#   g/VBD
#   a/DT
#   n/NN
#   i/NN
#   z/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#
# /CC
#   (Chunk Y/NNP)
#   o/MD
#   u/VB
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP M/NNP e/NN)
#   m/NN
#   b/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   s/VBD
#   u/JJ
#   r/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP k/NN)
#   (Chunk n/NNP)
#   o/VBZ
#   w/JJ
#   (Chunk  /NNP h/NN)
#   o/NN
#   w/IN
#    /NN
#   I/PRP
#    /VBP
#   f/JJ
#   e/NN
#   e/NN
#   l/NN
#   ./.
#    /CC
#   (Chunk O/NNP)
#   n/VBP
#   l/NN
#   y/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP y/NNP)
#   o/MD
#   u/VB
#   r/NN
#   (Chunk  /NNP h/NN)
#   e/NN
#   l/NN
#   p/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   I/PRP
#    /VBP
#   h/JJ
#   o/JJ
#   p/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NN
#   p/NN
#   l/NN
#   e/NN
#   t/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   t/VBZ
#   a/DT
#   s/JJ
#   k/NN
#   (Chunk s/VBD  /NNP e/NN)
#   v/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   g/VBP
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#    /JJ
#   p/NN
#   u/NN
#   b/IN
#   l/NN
#   i/NN
#   c/VBP
#    /JJ
#   s/NN
#   e/NN
#   r/NN
#   v/IN
#   a/DT
#   n/JJ
#   t/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   (Chunk  /NNP D/NNP i/NN)
#   v/VBP
#   i/NN
#   n/VBP
#   e/NN
#   (Chunk  /NNP g/NN)
#   u/NN
#   i/NN
#   d/VBP
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP y/NN)
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP h/NN)
#   e/NN
#   l/NN
#   p/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   n/VBP
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   w/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   s/JJ
#   s/NN
#   a/DT
#   g/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#    /JJ
#   f/NN
#   a/DT
#   r/NN
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   t/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ,/,
#    /VB
#   a/DT
#    /JJ
#   k/NN
#   i/NN
#   n/VBP
#   d/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   i/NN
#   e/VBP
#   n/JJ
#   d/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ,/,
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   ./.
#
# /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   f/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   a/DT
#   m/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   p/NN
#   e/NN
#   n/IN
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP y/NN)
#   o/NN
#   u/NN
#   ./.
#
# /CC
#   (Chunk T/NNP)
#   (Chunk o/VBP  /NNP d/NN)
#   e/NN
#   s/NN
#   t/NN
#   r/NN
#   o/NN
#   y/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   y/NN
#   r/VBZ
#   a/DT
#   n/JJ
#   t/NN
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP d/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP d/NN)
#   o/IN
#   m/NN
#   i/NN
#   n/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#   n/NN
#   o/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   s/NN
#   u/JJ
#   c/NN
#   c/NN
#   e/NN
#   s/JJ
#   s/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP g/NN)
#   e/NN
#   n/JJ
#   e/NN
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   c/JJ
#   r/NN
#   i/NN
#   f/VBP
#   i/JJ
#   c/VBP
#   e/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   n/VBP
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP y/NNP)
#   o/MD
#   u/VB
#   t/JJ
#   h/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   m/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/VBZ
#   a/DT
#   n/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   c/VBP
#   e/NN
#   n/JJ
#   c/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   v/VBP
#   i/JJ
#   l/NN
#   i/NN
#   z/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#    /VB
#   a/DT
#    /JJ
#   m/NN
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   t/NN
#   h/NN
#   o/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   c/NN
#   i/NN
#   d/VBP
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   f/VBP
#   f/NN
#   e/NN
#   r/NN
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   !/.
#   (Chunk
# /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /JJ
#   m/NN
#   u/JJ
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   s/VBP
#   t/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   f/NN
#   f/NN
#   e/NN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   h/NN
#   u/JJ
#   m/VBZ
#   a/DT
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#    /NN
#   b/VBD
#   a/DT
#   c/NN
#   k/NN
#    /VBZ
#   a/DT
#   l/NN
#   o/NN
#   n/JJ
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   i/JJ
#   s/VBP
#    /JJ
#   w/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   q/IN
#   u/JJ
#   i/NN
#   r/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   i/NN
#   m/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   l/NN
#   e/NN
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP s/NN)
#   h/VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#    /VBZ
#   a/DT
#   n/JJ
#    /NN
#   a/DT
#   b/NN
#   i/NN
#   d/VBP
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   i/JJ
#   t/NN
#   h/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP k/NN)
#   i/NN
#   n/VBP
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP)
#   f/VBD
#   a/DT
#   i/JJ
#   t/NN
#   h/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   r/NN
#   a/DT
#   g/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   k/NN
#   l/NN
#   i/NN
#   (Chunk n/VBP  /NNP D/NNP)
#   e/VBZ
#   l/VBZ
#   a/DT
#   n/JJ
#   o/NN
#   (Chunk  /NNP R/NNP)
#   o/MD
#   o/VB
#   s/JJ
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   t/NN
#    /VBZ
#   a/DT
#   l/NN
#   w/WRB
#   a/DT
#   y/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   d/NN
#   !/.
#
# /JJ
#   (Chunk T/NNP o/NN)
#   d/VBZ
#   a/DT
#   y/NN
#   ,/,
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#    /NN
#   h/NN
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   c/NN
#   o/IN
#   m/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   o/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP e/NN)
#   a/DT
#   r/NN
#   t/NN
#   h/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP k/NN)
#   e/NN
#   e/NN
#   p/IN
#    /NN
#   i/NN
#   t/VBP
#    /JJ
#   s/NN
#   o/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP)
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   c/JJ
#   h/NN
#   i/NN
#   e/VBP
#   v/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#    /JJ
#   w/NN
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   h/NN
#   i/JJ
#   p/VBP
#    /JJ
#   w/NN
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP d/NN)
#   o/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   l/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   l/VBP
#   i/NN
#   t/VBP
#   a/DT
#   r/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   v/NN
#   a/DT
#   l/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   ./.
#
# /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP)
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP)
#   c/VBP
#   o/JJ
#   m/NN
#   m/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   f/JJ
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   d/NN
#   o/JJ
#   m/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   (Chunk e/VBP  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   w/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP m/NN)
#   u/JJ
#   t/NN
#   u/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   o/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk W/NNP e/NN)
#   (Chunk  /NNP m/NN)
#   u/JJ
#   s/NN
#   t/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   a/DT
#   d/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   y/NN
#    /NN
#   b/NN
#   e/SYM
#   -/:
#   f/NN
#   o/JJ
#   r/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP m/NN)
#   u/JJ
#   t/NN
#   u/IN
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   d/NN
#   v/NN
#   a/DT
#   n/JJ
#   t/NN
#   a/DT
#   g/NN
#   e/SYM
#   -/:
#   i/NN
#   n/VBP
#   c/NN
#   r/NN
#   e/VBZ
#   a/DT
#   s/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   d/NN
#   u/JJ
#   c/NN
#   t/NN
#    /NN
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#   c/JJ
#   r/NN
#   e/VBZ
#   a/DT
#   s/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   e/VBZ
#   m/FW
#   p/NN
#   l/NN
#   o/NN
#   y/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   t/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   s/VBZ
#   t/VB
#   a/DT
#   n/JJ
#   d/NN
#   a/DT
#   r/NN
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP l/NN)
#   i/NN
#   v/VBP
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   o/NN
#   u/JJ
#   g/NN
#   h/NN
#   o/JJ
#   u/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   ./.
#
# /JJ
#   (Chunk M/NNP)
#   a/DT
#   y/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#   s/NN
#    /VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP g/NN)
#   l/NN
#   o/IN
#   r/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk  /NNP h/NN)
#   e/NN
#   r/NN
#   i/NN
#   t/VBP
#   a/DT
#   g/NN
#   e/NN
#   ./.
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   y/NN
#   ,/,
#   (Chunk  /VB A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   (Chunk  /NNP m/NN)
#   a/DT
#   y/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   l/NN
#   l/NN
#   (Chunk  /NNP l/NN)
#   e/VBZ
#   a/DT
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   l/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   s/NN
#   p/NN
#   e/NN
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   ./.
#
# /VB
#   A/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   m/NN
#   o/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   h/PDT
#   a/DT
#   v/NN
#   e/NN
#    /NN
#   i/NN
#   (Chunk n/VBP  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#    /VBZ
#   a/DT
#    /NN
#   p/NN
#   r/VBZ
#   a/DT
#   y/NN
#   e/NN
#   r/NN
#   ./.
#    /VB
#   A/DT
#   s/JJ
#    /NN
#   I/PRP
#    /VBP
#   h/PDT
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   m/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   v/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   i/NN
#   e/VBP
#   s/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   h/JJ
#   u/JJ
#   m/NN
#   b/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   a/DT
#   y/NN
#    /VBZ
#   A/DT
#   l/JJ
#   m/NN
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   y/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   d/VB
#   ,/,
#    /FW
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   o/NN
#   r/NN
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP K/NNP i/NNP)
#   n/VBP
#   g/NN
#   (Chunk  /NNP S/NNP)
#   o/MD
#   l/VB
#   o/JJ
#   m/NN
#   o/NN
#   n/NN
#   :/:
#
# /JJ
#   (Chunk "/NNP G/NNP i/NN)
#   v/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   f/NN
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   r/NN
#   v/IN
#   a/DT
#   n/JJ
#   t/NN
#    /VBD
#   a/DT
#   n/JJ
#    /NN
#   u/JJ
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   t/VBD
#   a/DT
#   n/JJ
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   h/NN
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP j/NN)
#   u/JJ
#   d/NN
#   g/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   y/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   h/VB
#   a/DT
#   t/NN
#    /NN
#   I/PRP
#    /VBP
#   m/VB
#   a/DT
#   y/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   c/NN
#   e/NN
#   r/NN
#   n/NN
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP g/NN)
#   o/NN
#   o/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   b/VBD
#   a/DT
#   d/NN
#   ;/:
#    /CC
#   f/VB
#   o/JJ
#   r/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   o/IN
#    /NN
#   i/NN
#   s/VBP
#    /PDT
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP j/NN)
#   u/JJ
#   d/NN
#   g/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   t/NN
#   h/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#    /VBZ
#   a/DT
#    /JJ
#   p/NN
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ?/.
#   "/JJ
#
# /NN
#   I/PRP
#    /VBP
#   a/DT
#   s/NN
#   k/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   b/NN
#   e/NN
#    /VBZ
#   a/DT
#    /JJ
#   g/NN
#   o/NN
#   o/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   f/VBZ
#   a/DT
#   i/JJ
#   t/NN
#   h/NN
#   f/JJ
#   u/JJ
#   l/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   r/NN
#   v/IN
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP L/NNP)
#   o/MD
#   r/VB
#   d/NN
#    /IN
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   ./.
#
# /NN)
